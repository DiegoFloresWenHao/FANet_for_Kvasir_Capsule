# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/datasets/Kvasir_Capsule_Seg.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/datasets/Kvasir_Capsule_Seg.zip
#    creating: /content/Kvasir_Capsule_Seg/images/
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28955.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28956.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28957.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28958.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28959.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28960.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28961.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28962.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28963.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28964.jpg
#   inflating: /content/Kvasir_Capsule_Seg/images/131368cc17e44240_28965.jpg
# ...

# %%
# !git clone https://github.com/nikhilroxtomar/FANet.git
# Out:
# Cloning into 'FANet'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 77 (delta 30), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (77/77), 555.99 KiB | 6.46 MiB/s, done.
# Resolving deltas: 100% (30/30), done.

# %%
# %cd FANet
# !python train.py
# Out:
# /content/FANet
# 2024-04-30 17:51:15.737480
# Dataset Size:
# Train: 33 - Valid: 22
#
# Dataset Size:
# Train: 33 - Valid: 22
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Hyperparameters:
# Image Size: (320, 320)
# Batch Size: 16
# LR: 0.0001
# Epochs: 200
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# 100% 33/33 [00:00<00:00, 59.36it/s]
# 100% 22/22 [00:00<00:00, 86.02it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Saving checkpoint: /content/drive/MyDrive/pre_trained_models/FANet_Kvasir_Capsule_Seg_checkpoint.pth
# Epoch: 01 | Epoch Time: 0m 8s
# 	Train Loss: 0.511
# ...

# %%
# %cd FANet
# !python test.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# 100% 22/22 [00:00<00:00, 91.26it/s]
# 100% 22/22 [00:02<00:00,  9.69it/s]
# Mean Time Taken:  0.04550542614676736
# Jaccard: 0.8506 - F1: 0.9178 - Recall: 0.9380 - Precision: 0.9028 - Specificity: 0.8800 - Acc: 0.9136 - F2: 0.9291 - Mean Time: 0.0455054 - Mean FPS: 21.9754013
# 100% 22/22 [00:02<00:00,  9.46it/s]
# Mean Time Taken:  0.02791464328765869
# Jaccard: 0.8533 - F1: 0.9192 - Recall: 0.9439 - Precision: 0.9002 - Specificity: 0.8754 - Acc: 0.9148 - F2: 0.9332 - Mean Time: 0.0279146 - Mean FPS: 35.8234920
# 100% 22/22 [00:01<00:00, 12.00it/s]
# Mean Time Taken:  0.023756428198380905
# Jaccard: 0.8538 - F1: 0.9195 - Recall: 0.9452 - Precision: 0.8995 - Specificity: 0.8742 - Acc: 0.9150 - F2: 0.9341 - Mean Time: 0.0237564 - Mean FPS: 42.0938700
# 100% 22/22 [00:01<00:00, 14.74it/s]
# Mean Time Taken:  0.0190254883332686
# ...

# %% [markdown]
# # **Second Run**

# %%
# %cd FANet
# !python train.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# Log file exists
# 2024-04-30 18:10:25.452607
# Dataset Size:
# Train: 33 - Valid: 22
#
# Dataset Size:
# Train: 33 - Valid: 22
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Hyperparameters:
# Image Size: (320, 320)
# Batch Size: 16
# LR: 1e-06
# Epochs: 200
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# 100% 33/33 [00:00<00:00, 66.83it/s]
# 100% 22/22 [00:00<00:00, 52.17it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...

# %%
# %cd FANet
# !python test.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# 100% 22/22 [00:00<00:00, 86.29it/s]
# 100% 22/22 [00:02<00:00, 10.52it/s]
# Mean Time Taken:  0.042562679810957474
# Jaccard: 0.8511 - F1: 0.9180 - Recall: 0.9374 - Precision: 0.9038 - Specificity: 0.8815 - Acc: 0.9140 - F2: 0.9289 - Mean Time: 0.0425627 - Mean FPS: 23.4947612
# 100% 22/22 [00:01<00:00, 14.58it/s]
# Mean Time Taken:  0.019239512356844814
# Jaccard: 0.8540 - F1: 0.9197 - Recall: 0.9439 - Precision: 0.9010 - Specificity: 0.8765 - Acc: 0.9153 - F2: 0.9334 - Mean Time: 0.0192395 - Mean FPS: 51.9763693
# 100% 22/22 [00:01<00:00, 14.56it/s]
# Mean Time Taken:  0.019305554303255947
# Jaccard: 0.8545 - F1: 0.9199 - Recall: 0.9452 - Precision: 0.9003 - Specificity: 0.8754 - Acc: 0.9155 - F2: 0.9343 - Mean Time: 0.0193056 - Mean FPS: 51.7985645
# 100% 22/22 [00:02<00:00, 10.61it/s]
# Mean Time Taken:  0.026503237811001865
# ...

# %% [markdown]
# # **New Split**

# %%
# %cd FANet
# !python train.py
# Out:
# /content/FANet
# 2024-04-30 20:15:01.616454
# Dataset Size:
# Train: 44 - Valid: 11
#
# Dataset Size:
# Train: 44 - Valid: 11
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Hyperparameters:
# Image Size: (320, 320)
# Batch Size: 16
# LR: 5e-05
# Epochs: 300
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# 100% 44/44 [00:00<00:00, 70.21it/s]
# 100% 11/11 [00:00<00:00, 83.94it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Saving checkpoint: /content/drive/MyDrive/pre_trained_models/FANet_Kvasir_Capsule_Seg_checkpoint_80-20_split.pth
# Epoch: 01 | Epoch Time: 0m 7s
# ...

# %%
# %cd FANet
# !python test.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# 100% 11/11 [00:00<00:00, 88.58it/s]
# 100% 11/11 [00:01<00:00,  8.03it/s]
# Mean Time Taken:  0.0665404579856179
# Jaccard: 0.8550 - F1: 0.9203 - Recall: 0.9599 - Precision: 0.8880 - Specificity: 0.8579 - Acc: 0.9144 - F2: 0.9430 - Mean Time: 0.0665405 - Mean FPS: 15.0284508
# 100% 11/11 [00:00<00:00, 14.05it/s]
# Mean Time Taken:  0.019886862147938122
# Jaccard: 0.8617 - F1: 0.9242 - Recall: 0.9630 - Precision: 0.8923 - Specificity: 0.8674 - Acc: 0.9194 - F2: 0.9466 - Mean Time: 0.0198869 - Mean FPS: 50.2844538
# 100% 11/11 [00:00<00:00, 14.41it/s]
# Mean Time Taken:  0.01828191497109153
# Jaccard: 0.8596 - F1: 0.9229 - Recall: 0.9663 - Precision: 0.8872 - Specificity: 0.8574 - Acc: 0.9174 - F2: 0.9479 - Mean Time: 0.0182819 - Mean FPS: 54.6988651
# 100% 11/11 [00:00<00:00, 14.37it/s]
# Mean Time Taken:  0.018966544758189808
# ...

# %%
# %cd FANet
# !python train.py # batch size = 2
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# Log file exists
# 2024-04-30 20:44:40.455088
# Dataset Size:
# Train: 44 - Valid: 11
#
# Dataset Size:
# Train: 44 - Valid: 11
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Hyperparameters:
# Image Size: (320, 320)
# Batch Size: 2
# LR: 5e-05
# Epochs: 300
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# 100% 44/44 [00:00<00:00, 72.86it/s]
# 100% 11/11 [00:00<00:00, 87.71it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ...

# %%
# %cd FANet
# !python test.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# 100% 11/11 [00:00<00:00, 85.96it/s]
# 100% 11/11 [00:01<00:00,  8.30it/s]
# Mean Time Taken:  0.06196592070839622
# Jaccard: 0.8764 - F1: 0.9331 - Recall: 0.9717 - Precision: 0.9001 - Specificity: 0.8695 - Acc: 0.9277 - F2: 0.9555 - Mean Time: 0.0619659 - Mean FPS: 16.1379027
# 100% 11/11 [00:00<00:00, 14.72it/s]
# Mean Time Taken:  0.018984859639948063
# Jaccard: 0.8792 - F1: 0.9347 - Recall: 0.9737 - Precision: 0.9013 - Specificity: 0.8770 - Acc: 0.9302 - F2: 0.9574 - Mean Time: 0.0189849 - Mean FPS: 52.6735524
# 100% 11/11 [00:00<00:00, 14.65it/s]
# Mean Time Taken:  0.019782434810291637
# Jaccard: 0.8769 - F1: 0.9335 - Recall: 0.9743 - Precision: 0.8983 - Specificity: 0.8691 - Acc: 0.9283 - F2: 0.9572 - Mean Time: 0.0197824 - Mean FPS: 50.5498949
# 100% 11/11 [00:00<00:00, 15.12it/s]
# Mean Time Taken:  0.019116748463023792
# ...

# %% [markdown]
# # **256 x 256 Resolution**

# %%
# %cd FANet
# !python train.py # batch size = 2
# Out:
# /content/FANet
# 2024-04-30 22:23:54.923942
# Dataset Size:
# Train: 44 - Valid: 11
#
# Dataset Size:
# Train: 44 - Valid: 11
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Hyperparameters:
# Image Size: (256, 256)
# Batch Size: 2
# LR: 5e-05
# Epochs: 400
# Optimizer: Adam
# Loss: BCE Dice Loss
#
# 100% 44/44 [00:00<00:00, 99.26it/s]
# 100% 11/11 [00:00<00:00, 113.41it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Saving checkpoint: /content/drive/MyDrive/pre_trained_models/FANet_Kvasir_Capsule_Seg_Res_256x256_checkpoint_80-20_split_batch_size_2.pth
# ...

# %%
# %cd FANet
# !python test.py
# Out:
# [Errno 2] No such file or directory: 'FANet'
# /content/FANet
# 100% 11/11 [00:00<00:00, 129.50it/s]
# 100% 11/11 [00:01<00:00,  9.88it/s]
# Mean Time Taken:  0.06588482856750488
# Jaccard: 0.8909 - F1: 0.9413 - Recall: 0.9574 - Precision: 0.9283 - Specificity: 0.9239 - Acc: 0.9392 - F2: 0.9505 - Mean Time: 0.0658848 - Mean FPS: 15.1780011
# 100% 11/11 [00:00<00:00, 20.33it/s]
# Mean Time Taken:  0.019800077785145153
# Jaccard: 0.8914 - F1: 0.9416 - Recall: 0.9601 - Precision: 0.9263 - Specificity: 0.9202 - Acc: 0.9394 - F2: 0.9523 - Mean Time: 0.0198001 - Mean FPS: 50.5048521
# 100% 11/11 [00:00<00:00, 20.99it/s]
# Mean Time Taken:  0.02042932943864302
# Jaccard: 0.8902 - F1: 0.9409 - Recall: 0.9604 - Precision: 0.9247 - Specificity: 0.9175 - Acc: 0.9385 - F2: 0.9522 - Mean Time: 0.0204293 - Mean FPS: 48.9492327
# 100% 11/11 [00:00<00:00, 21.14it/s]
# Mean Time Taken:  0.018273245204578747
# ...
